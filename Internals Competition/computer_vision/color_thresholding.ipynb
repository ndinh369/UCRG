# %%
# Import libraries
import cv2 
import numpy as np

def nothing(x): pass

# Load image
image = cv2.imread('dates_1.jpg')

# Create a window
cv2.namedWindow('image', cv2.WINDOW_NORMAL) 
cv2.resizeWindow('image', 900, 700)

# Create trackbars for color change
# Hue is from 0-179 for Opencv
cv2.createTrackbar('HMin', 'image', 0, 179, nothing) 
cv2.createTrackbar('SMin', 'image', 0, 255, nothing) 
cv2.createTrackbar('VMin', 'image', 0, 255, nothing) 
cv2.createTrackbar('HMax', 'image', 0, 179, nothing) 
cv2.createTrackbar('SMax', 'image', 0, 255, nothing) 
cv2.createTrackbar('VMax', 'image', 0, 255, nothing)

# Set default value for Max HSV trackbars
cv2.setTrackbarPos('HMax', 'image', 179) 
cv2.setTrackbarPos('SMax', 'image', 255) 
cv2.setTrackbarPos('VMax', 'image', 255)

# Initialize HSV min/max values
hMin = sMin = vMin = hMax = sMax = vMax = 0 
phMin = psMin = pvMin = phMax = psMax = pvMax = 0

while(1):

    # Get current positions of all trackbars
    hMin = cv2.getTrackbarPos('HMin', 'image')
    sMin = cv2.getTrackbarPos('SMin', 'image')
    vMin = cv2.getTrackbarPos('VMin', 'image')
    hMax = cv2.getTrackbarPos('HMax', 'image')
    sMax = cv2.getTrackbarPos('SMax', 'image')
    vMax = cv2.getTrackbarPos('VMax', 'image')

    # Set minimum and maximum HSV values to display
    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    # Convert to HSV format and color threshold
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    result = cv2.bitwise_and(image, image, mask=mask)
    
    # Convert grayscale image to color image for displaying simultaneous
    mask_3_channel = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
    
    # Stack images
    numpy_horizontal = np.hstack((image, result, mask_3_channel))
    
    # Display HSV values of some colours
    cv2.putText(numpy_horizontal, 'Black: (0, 0, 0)', (130, 15), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)
    cv2.putText(numpy_horizontal, 'White: (0, 0, 255)', (130, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)
    cv2.putText(numpy_horizontal, 'Red: (0, 255, 255)', (130, 45), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)
    cv2.putText(numpy_horizontal, 'Green: (60, 255, 255)', (130, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)
    cv2.putText(numpy_horizontal, 'Blue: (120, 255, 255)', (130, 75), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)

    # Print if there is a change in HSV value
    if((phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    # Display stacked image, press q to quit
    cv2.imshow('image', numpy_horizontal)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cv2.destroyAllWindows()
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 1, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 6, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 18, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 38, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 39, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 42, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 44, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 46, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 47, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 48, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 50, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 52, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 53, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 54, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 55, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 56, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 57, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 58, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 59, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 64, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 66, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 68, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 71, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 75, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 76, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 78, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 82, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 84, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 86, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 88, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 90, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 92, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 93, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 95, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 96, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 97, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 98, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 99, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 100, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 101, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 103, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 104, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 105, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 106, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 107, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 108, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 109, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 108, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 103, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 90, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 83, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 81, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 79, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 78, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 76, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 75, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 73, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 2 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 8 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 14 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 15 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 17 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 19 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 17 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 15 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 8 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 7 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 4 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 2 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 1), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 5), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 7), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 10), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 13), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 15), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 16), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 17), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 18), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 19), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 22), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 24), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 25), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 26), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 27), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 30), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 33), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 34), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 35), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 37), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 38), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 39), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 40), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 41), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 42), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 43), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 45), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 59), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 79), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 99), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 111), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 115), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 119), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 121), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 122), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 123), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 122), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 121), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 118), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 114), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 105), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 103), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 99), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 98), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 96), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 95), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 94), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 93), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 90), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 87), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 85), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 82), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 80), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 77), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 73), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 71), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 69), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 68), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 67), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 66), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 65), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 63), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 61), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 59), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 57), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 55), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 53), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 51), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 50), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 49), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 48), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 46), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 44), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 43), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 42), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 40), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 38), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 35), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 34), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 33), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 32), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 31), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 30), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 178 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 171 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 166 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 162 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 159 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 156 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 154 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 153 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 152 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 151 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 150 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 149 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 148 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 145 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 140 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 133 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 128 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 124 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 121 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 119 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 118 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 117 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 116 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 111 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 106 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 98 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 94 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 90 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 89 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 88 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 87 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 86 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 85 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 84 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 83 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 81 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 80 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 78 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 77 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 76 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 74 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 70 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 65 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 63 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 62 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 61 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 54 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 51 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 50 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 48 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 47 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 46 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 45 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 44 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 42 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 39 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 36 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 35 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 34 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 33 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 30 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 27 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 26 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 25 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 24 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 22 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 20 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 17 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 14 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 13 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 12 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 13 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 14 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 15 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 16 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 17 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 18 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 20 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 21 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 20 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 4 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 7 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 4 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 27), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 26), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 25), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 24), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 22), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 21), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 20), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 19), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 18), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 17), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 16), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 15), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 14), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 13), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 12), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 11), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 10), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 9), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 8), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 7), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 6), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 5), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 4), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 3), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 2), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 1), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 0), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 1), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 3), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 4), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 5), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 7), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 9), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 12), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 14), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 16), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 17), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 18), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 19), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 20), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 21), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 22), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 24), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 25), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 26), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 27), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 31), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 33), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 35), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 37), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 38), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 39), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 40), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 41), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 42), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 43), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 44), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 45), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 46), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 47), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 45), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 44), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 43), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 42), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 41), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 38), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 36), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 33), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 30), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 27), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 26), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 24), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 22), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 21), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 22), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 24), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 25), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 26), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 27), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 29), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 30), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 32), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 33), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 34), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 35), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 34), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 33), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 32), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 30), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 29), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 28), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 27), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 26), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 25), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 24), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 73, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 72, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 71, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 70, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 69, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 68, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 67, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 66, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 65, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 64, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 63, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 61, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 60, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 59, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 58, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 57, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 56, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 55, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 54, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 53, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 52, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 51, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 50, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 49, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 48, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 47, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 46, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 45, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 44, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 43, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 42, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 41, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 40, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 39, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 38, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 36, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 35, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 33, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 32, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 31, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 30, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 29, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 28, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 27, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 26, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 25, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 24, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 23, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 22, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 21, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 20, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 19, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 18, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 17, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 16, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 15, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 14, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 13, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 12, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 11, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 9, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 8, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 7, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 6, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 5, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 4, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 3, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 2, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 254, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 252, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 247, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 240, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 235, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 233, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 232, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 230, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 227, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 225, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 224, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 223, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 222, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 221, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 222, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 228, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 241, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 252, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 254)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 252)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 250)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 247)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 245)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 242)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 240)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 238)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 235)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 233)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 231)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 230)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 229)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 225)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 219)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 218)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 215)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 214)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 213)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 211)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 204)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 196)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 187)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 175)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 164)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 159)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 157)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 156)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 155)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 148)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 135)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 129)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 127)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 126)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 125)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 124)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 123)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 120)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 119)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 118)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 117)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 116)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 113)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 110)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 108)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 107)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 106)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 105)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 104)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 103)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 102)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 101)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 100)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 98)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 99)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 106)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 109)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 115)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 118)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 121)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 123)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 125)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 126)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 129)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 131)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 133)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 135)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 139)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 143)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 147)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 149)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 152)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 153)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 154)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 155)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 156)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 158)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 159)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 160)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 161)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 162)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 163)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 164)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 165)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 166)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 167)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 169)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 171)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 177)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 179)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 181)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 182)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 183)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 185)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 187)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 190)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 192)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 193)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 192)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 191)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 190)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 189)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 188)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 187)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 184)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 182)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 181)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 180)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 178)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 177)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 175)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 174)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 173)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 172)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 171)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 170)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 169)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 168)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 166)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 164)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 163)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 162)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 161)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 160)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 161)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 163)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 166)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 169)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 171)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 172)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 173)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 174)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 175)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 176)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 178)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 179)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 180)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 181)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 182)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 183)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 184)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 185)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 20 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 21 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 22 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 23 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 24 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 25 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 26 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 25 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 23 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 22 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 21 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 20 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 19 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 18 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 16 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 15 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 14 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 15 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 16 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 16 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 15 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 14 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 13 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 12 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 13 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 12 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 13 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 14 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 15 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 16 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 16 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 15 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 16 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 2, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 3, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 7, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 8, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 10, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 14, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 16, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 18, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 19, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 21, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 23, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 25, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 28, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 31, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 35, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 38, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 41, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 42, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 45, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 47, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 48, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 49, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 50, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 51, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 52, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 53, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 54, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 55, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 56, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 58, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 59, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 62, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 64, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 66, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 68, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 69, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 70, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 71, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 72, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 73, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 74, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 75, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 76, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 77, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 78, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 79, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 80, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 81, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 82, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 83, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 84, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 85, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 86, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 84, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 83, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 81, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 79, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 73, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 70, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 68, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 66, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 65, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 63, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 62, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 61, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 60, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 59, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 58, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 59, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 60, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
# (hMin = 0 , sMin = 61, vMin = 23), (hMax = 17 , sMax = 255, vMax = 186)
